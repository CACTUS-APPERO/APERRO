# %% [markdown]
# # AP(P)3RO PROJECT #
#
# ### Projet de deneigement intelligent de Montréal, Canada ###
#
# #### M. Le Gras, A. Naullet, A. Calixte, P. Beaunieux ####

# %%
import multiprocessing as mp

import numpy as np
import osmnx as ox

# %% [markdown]
# ## Partie 1: Cartographie de la ville par le drone ##

# %%
place = "Caen, France" # /!\ Replace with Montreal
G = ox.graph_from_place(place, network_type="drive")
#Gp = ox.project_graph(G)

# %% [markdown]
# ### 1.1: Importation des plans de la ville ###

# %%
ox.plot_graph(G)
# Out:
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)

# %%
node1 =list(G.nodes(data=True))[2][0]
node2 =list(G.nodes(data=True))[42][0]
print(list(G.nodes(data=True))[42])
print(node1, node2)
# Out:
# (25974872, {'y': 49.1746918, 'x': -0.3888363, 'street_count': 3})
# 16825440 25974872

# %%
route = ox.shortest_path(G, node1, node2)
print(route)
fig, ax = ox.plot_graph_route(G, route, route_linewidth=6, node_size=0, bgcolor='black')
# Out:
# [16825440, 16825442, 16825443, 1331033047, 1748526024, 1748526262, 1907920689, 1748526031, 1748526141, 1748530200, 2054413483, 1748530224, 1748526329, 1748526186, 2054413474, 1748526290, 1748526085, 1748526254, 1748526269, 105457329, 105457334, 26171481, 1748526023, 1829388023, 2017284255, 1829388099, 1829388092, 26019478, 26019477, 26290394, 266647161, 26290396, 26290398, 1978088429, 26019470, 114203847, 114203860, 26290401, 26081356, 146169346, 29193420, 127391563, 26081364, 26081366, 316408119, 26081371, 301509831, 102994969, 127391553, 315011536, 26016096, 2364229842, 1979474660, 1795010076, 5275462052, 26003111, 25975013, 26003117, 26472906, 240957320, 26525724, 1901843167, 26081305, 26169347, 26472911, 3258623205, 240957397, 240957404, 240957388, 127391533, 26472919, 107476262, 26472921, 26472920, 2132340942, 240957584, 240957575, 1378817699, 25974872]

# %% [markdown]
# ### 1.2 Calcul du parcours le plus efficace pour le drone ###

# %%
#ICI on fait l'algo

# %%
# ICI ON AFFICHE
#fig, ax = ox.plot_graph_route(G, route, route_linewidth=6, node_size=0, bgcolor='k') --> afficher le parcours avec une liste noeud

# %% [markdown]
# ### 1.3 Recuperation des données du drones (simulation d'eneigement) ###
